# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# # Question 1

# %%
df = pd.read_csv('bankloan.csv')
df.describe()
# Out:
#            Row ID            id     member_id      loan_amnt    funded_amnt  \
# count  368.000000  2.129990e+05  2.129990e+05  212999.000000  212999.000000
# mean   184.500000  6.103515e+07  6.515927e+07   15257.965530   15257.965530
# std    106.376689  4.734904e+06  5.215173e+06    8611.713377    8611.713377
# min      1.000000  5.670500e+04  7.082500e+04    1000.000000    1000.000000
# 25%     92.750000  5.783411e+07  6.158651e+07    8500.000000    8500.000000
# 50%    184.500000  6.137900e+07  6.549753e+07   14000.000000   14000.000000
# 75%    276.250000  6.503778e+07  6.956436e+07   20000.000000   20000.000000
# max    368.000000  6.861687e+07  7.351969e+07   35000.000000   35000.000000
#
#             int_rate    installment    annual_inc            dti  \
# count  212999.000000  212999.000000  2.129990e+05  212999.000000
# mean       12.401658     440.842921  7.780071e+04      19.360817
# std         4.249365     245.858646  8.188065e+04      31.925871
# ...

# %%
profile = ProfileReport(df)

# %%
profile.to_file('report.html')
# Out:
# ...
# 100%|██████████| 53/53 [00:02<00:00, 25.20it/s]
# /Users/thanasisxan/repos/AI-101-Machine-Learning/.venv/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /Users/thanasisxan/repos/AI-101-Machine-Learning/.venv/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /Users/thanasisxan/repos/AI-101-Machine-Learning/.venv/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /Users/thanasisxan/repos/AI-101-Machine-Learning/.venv/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
# ...

# %% [markdown]
# # Question 2

# %% [markdown]
# ## 1.

# %% [markdown]
# * mean: 15257.966
# * max: 35000
# * min: 1000

# %% [markdown]
# ## 2.

# %%
df.columns
# Out:
# Index(['Row ID', 'id', 'member_id', 'loan_amnt', 'funded_amnt', 'term',
#        'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'title', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'mths_since_last_delinq',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'total_pymnt', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'next_pymnt_d', 'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'application_type', 'annual_inc_joint',
#        'dti_joint', 'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal',
#        'total_rev_hi_lim', 'Unnamed: 50', '36months', '60months'],
#       dtype='object')

# %% [markdown]
# Variables to drop for training:
# * Row ID
# * id
# * member_id
# * Unnamed: 50
# * 36months
# * 60months
# * acc_now_delinq
# * delinq_2yrs
# * dti
# * application_type
# * collections_12_mths_ex_med
# * collection_recovery_fee
# * recoveries
# * total_rec_late_fee
# * issue_d
# * loan_status
# * emp_title
# * desc
# * addr_state
# * zip_code
# * earliest_cr_line
# * grade
# * sub_grade

# %%
df.drop(columns=[
    'Row ID', 'id', 'member_id', 'Unnamed: 50', '36months', '60months',
    'acc_now_delinq', 'delinq_2yrs', 'dti', 'application_type',
    'collections_12_mths_ex_med', 'collection_recovery_fee', 'recoveries',
    'total_rec_late_fee', 'issue_d', 'loan_status', 'emp_title',
    'earliest_cr_line', 'grade','last_pymnt_d','mths_since_last_major_derog'
], inplace=True)

# %% [markdown]
# # Question 3

# %%
get_loan = ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2']  # with this subgrade they get loan
df['target'] = df['sub_grade'].isin(get_loan).astype(int)  # 0 dont get loan, 1 get loan
df.drop(columns=['sub_grade'], inplace=True)

# %%
df.isnull().sum()
# Out:
# loan_amnt                           0
# funded_amnt                         0
# term                                0
# int_rate                            0
# installment                         0
# emp_length                      12767
# home_ownership                      0
# annual_inc                          0
# verification_status                 0
# purpose                             0
# title                              15
# inq_last_6mths                      0
# mths_since_last_delinq         103371
# open_acc                            0
# pub_rec                             0
# revol_bal                           0
# revol_util                         82
# total_acc                           0
# initial_list_status                 0
# out_prncp                           0
# total_pymnt                         0
# total_rec_prncp                     0
# total_rec_int                       0
# last_pymnt_d                     8489
# last_pymnt_amnt                     0
# ...
